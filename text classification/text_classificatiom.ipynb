# %%
# download ktrain
# !pip install ktrain
# Out:
# Requirement already satisfied: ktrain in /home/thethanh02/.local/lib/python3.8/site-packages (0.36.0)
# Requirement already satisfied: transformers>=4.17.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (4.28.1)
# Requirement already satisfied: jieba in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (0.42.1)
# Requirement already satisfied: sentencepiece in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (0.1.98)
# Requirement already satisfied: requests in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (2.28.2)
# Requirement already satisfied: chardet in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (3.0.4)
# Requirement already satisfied: joblib in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (1.2.0)
# Requirement already satisfied: whoosh in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (2.7.4)
# Requirement already satisfied: scikit-learn in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (1.2.2)
# Requirement already satisfied: packaging in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (23.1)
# Requirement already satisfied: fastprogress>=0.1.21 in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (1.0.3)
# Requirement already satisfied: langdetect in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (1.0.9)
# Requirement already satisfied: pandas>=1.0.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (1.5.1)
# Requirement already satisfied: tika in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (2.6.0)
# Requirement already satisfied: syntok>1.3.3 in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (1.4.4)
# Requirement already satisfied: matplotlib>=3.0.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (3.7.0)
# Requirement already satisfied: keras-bert>=0.86.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (0.89.0)
# Requirement already satisfied: cchardet in /home/thethanh02/.local/lib/python3.8/site-packages (from ktrain) (2.1.7)
# Requirement already satisfied: filelock in /home/thethanh02/.local/lib/python3.8/site-packages (from transformers>=4.17.0->ktrain) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /home/thethanh02/.local/lib/python3.8/site-packages (from transformers>=4.17.0->ktrain) (4.65.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from transformers>=4.17.0->ktrain) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from transformers>=4.17.0->ktrain) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from transformers>=4.17.0->ktrain) (0.13.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/thethanh02/.local/lib/python3.8/site-packages (from transformers>=4.17.0->ktrain) (2022.9.13)
# Requirement already satisfied: numpy>=1.17 in /home/thethanh02/.local/lib/python3.8/site-packages (from transformers>=4.17.0->ktrain) (1.22.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/thethanh02/.local/lib/python3.8/site-packages (from requests->ktrain) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/thethanh02/.local/lib/python3.8/site-packages (from requests->ktrain) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/thethanh02/.local/lib/python3.8/site-packages (from requests->ktrain) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from requests->ktrain) (1.26.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from scikit-learn->ktrain) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/thethanh02/.local/lib/python3.8/site-packages (from scikit-learn->ktrain) (1.9.1)
# Requirement already satisfied: six in /home/thethanh02/.local/lib/python3.8/site-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from pandas>=1.0.1->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from pandas>=1.0.1->ktrain) (2022.4)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tika->ktrain) (45.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->ktrain) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->ktrain) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/thethanh02/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->ktrain) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/thethanh02/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->ktrain) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/thethanh02/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->ktrain) (2.4.7)
# Requirement already satisfied: keras-transformer==0.40.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from keras-bert>=0.86.0->ktrain) (0.40.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/thethanh02/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers>=4.17.0->ktrain) (4.4.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/thethanh02/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.0.0->ktrain) (3.15.0)
# Requirement already satisfied: keras-position-wise-feed-forward==0.8.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.8.0)
# Requirement already satisfied: keras-multi-head==0.29.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.29.0)
# Requirement already satisfied: keras-embed-sim==0.10.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.10.0)
# Requirement already satisfied: keras-layer-normalization==0.16.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.16.0)
# Requirement already satisfied: keras-pos-embd==0.13.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.13.0)
# Requirement already satisfied: keras-self-attention==0.51.0 in /home/thethanh02/.local/lib/python3.8/site-packages (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.51.0)

# %%
#import ktrain and the ktrain.text modules
import ktrain
from ktrain import text

# %%
# read the dataset
import pandas as pd
from sklearn.model_selection import train_test_split

train_dataset = pd.read_csv("datasets/train.csv")
test_dataset = pd.read_csv("datasets/test.csv")
valid_dataset = pd.read_csv("datasets/val.csv")

list_dataset = [train_dataset, test_dataset, valid_dataset]

dataset = pd.concat(list_dataset)

Xfeatures = dataset['Text']
ylabels = dataset['Emotion']

#  Split Data
x_train, x_test, y_train, y_test = train_test_split(Xfeatures, ylabels, test_size=0.1, random_state=41)

# convert pandas series to list
x_train = x_train.tolist()
x_test = x_test.tolist()
y_train = y_train.tolist()
y_test = y_test.tolist()

# %%
# Create a Transformer instance
MODEL_NAME = 'distilbert-base-uncased'
MAX_LEN = 256 # maximum sequence length. The longest sequence in our training set is 47.
class_names = ['anger', 'fear', 'joy', 'love', 'sadness', 'surprise']
t = text.Transformer(MODEL_NAME, MAX_LEN, class_names=class_names)

# %%
# Preprocess the Datasets
trn = t.preprocess_train(x_train, y_train)
val = t.preprocess_test(x_test, y_test)
# Out:
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 19
# 	95percentile : 41
# 	99percentile : 52
# /home/thethanh02/.local/lib/python3.8/site-packages/ktrain/utils.py:744: UserWarning: class_names argument was ignored, as they were extracted from string labels in dataset
#   warnings.warn(

# %%
# Create a Model and Wrap in Learner
model = t.get_classifier()
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=12)

# %%
# Estimate a Good Learning Rate
learner.lr_find(show_plot=True, max_epochs=2)
# Out:
# simulating training for different learning rates... this may take a few moments...
# Epoch 1/2
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Train Model
learner.fit_onecycle(5e-5, 6)

# %%
# Evaluate/Inspect Model
learner.validate(class_names = class_names)

# %%
# the one we got most wrong
learner.view_top_losses(n=1, preproc=t)

# %%
# Make Predictions on New Data
predictor = ktrain.get_predictor(learner.model, preproc=t)
predictor.predict("I can't imagine how hard it must be for you.")

# %% [markdown]
# # Save Model

# %%
# save Predictor (i.e., model and Preprocessor instance) after partially training
predictor.save("/saved_model")

# %% [markdown]
# # Load Model

# %%
# reload Predictor and extract model
#model = ktrain.load_predictor('/content/saved_model')
